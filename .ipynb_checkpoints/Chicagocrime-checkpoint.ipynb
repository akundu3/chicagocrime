# %%
import os
import numpy as np
import pandas as pd
from sodapy import Socrata

# %%
socrata_domain = 'data.cityofchicago.org'
socrata_dataset_identifier = '6zsd-86xi'
socrata_token = os.environ.get("SODAPY_APPTOKEN")

# %%
client = Socrata(socrata_domain, socrata_token)
print("Domain: {domain:}\nSession: {session:}\nURI Prefix: {uri_prefix:}".format(**client.__dict__))
# Out:
# Domain: data.cityofchicago.org
# Session: <requests.sessions.Session object at 0x1180db978>
# URI Prefix: https://

# %%
results1 = client.get(socrata_dataset_identifier, limit = 50000)
df1 = pd.DataFrame.from_dict(results1)
df1.head()
# Out:
#    arrest  beat                    block case_number community_area  \
# 0   False  0412          016XX E 86TH PL    JA366925             45
# 1    True  1034  026XX S CALIFORNIA BLVD    JA529032             30
# 2    True  1221  007XX N SACRAMENTO BLVD    JA545986             23
# 3   False  2222       092XX S RACINE AVE    JB147188             73
# 4   False  0835          026XX W 79TH ST    JB147595             70
#
#                       date                            description district  \
# 0  2001-01-01T11:00:00.000    FINANCIAL IDENTITY THEFT OVER $ 300      004
# 1  2017-11-28T21:43:00.000  VIOLENT OFFENDER: ANNUAL REGISTRATION      010
# 2  2017-12-11T19:15:00.000                         ARMED: HANDGUN      012
# 3  2017-10-08T03:00:00.000                         NON-AGGRAVATED      022
# 4  2017-03-28T14:00:00.000                         UNLAWFUL ENTRY      008
#
#    domestic fbi_code  ...       latitude  \
# 0     False       11  ...            NaN
# ...

# %%
results2 = client.get(socrata_dataset_identifier, limit = 50000, offset = 50000)
df2 = pd.DataFrame.from_dict(results2)
df2.shape
# Out:
# (50000, 22)

# %%
results3 = client.get(socrata_dataset_identifier, limit = 50000, offset = 100000)
df3 = pd.DataFrame.from_dict(results3)
df3.shape
# Out:
# (50000, 22)

# %%
df.shape
# Out:
# (50000, 22)

# %%
df1.tail(3)
# Out:
#        arrest  beat                              block case_number  \
# 49997   False  0513  108XX S DR MARTN LUTHR KING JR DR     G022858
# 49998    True  0232               051XX S WENTWORTH AV     G023025
# 49999   False  1233                      008XX W 19 ST     G023121
#
#       community_area                     date                     description  \
# 49997            NaN  2001-01-05T18:00:00.000                      TO VEHICLE
# 49998            NaN  2001-01-11T18:00:00.000  SEX OFFENDER: FAIL TO REGISTER
# 49999            NaN  2001-01-10T21:00:00.000                  $500 AND UNDER
#
#       district  domestic fbi_code  ...       latitude  \
# 49997      005     False       14  ...   41.697707155
# 49998      002     False       26  ...   41.801809043
# 49999      012     False       06  ...   41.856840968
#
#                                                 location  \
# 49997  {'type': 'Point', 'coordinates': [-87.61336371...
# ...

# %%
iucrc = pd.read_csv('Chicago_Police_Department_-_Illinois_Uniform_Crime_Reporting__IUCR__Codes.csv')

# %%
iucrc
# Out:
#      IUCR  PRIMARY DESCRIPTION  \
# 0     110             HOMICIDE
# 1     130             HOMICIDE
# 2     141             HOMICIDE
# 3     142             HOMICIDE
# 4     261  CRIM SEXUAL ASSAULT
# 5     262  CRIM SEXUAL ASSAULT
# 6     263  CRIM SEXUAL ASSAULT
# 7     264  CRIM SEXUAL ASSAULT
# 8     265  CRIM SEXUAL ASSAULT
# 9     266  CRIM SEXUAL ASSAULT
# 10    271  CRIM SEXUAL ASSAULT
# 11    272  CRIM SEXUAL ASSAULT
# 12    273  CRIM SEXUAL ASSAULT
# 13    274  CRIM SEXUAL ASSAULT
# 14    275  CRIM SEXUAL ASSAULT
# 15    281  CRIM SEXUAL ASSAULT
# 16    291  CRIM SEXUAL ASSAULT
# 17    312              ROBBERY
# 18    313              ROBBERY
# 19   031A              ROBBERY
# 20   031B              ROBBERY
# 21    320              ROBBERY
# 22    325              ROBBERY
# 23    326              ROBBERY
# 24    330              ROBBERY
# 25    331              ROBBERY
# 26    334              ROBBERY
# 27    337              ROBBERY
# 28   033A              ROBBERY
# ...

# %%
df2.head(5)
# Out:
#    arrest  beat                 block case_number community_area  \
# 0   False  2113    029XX S FEDERAL ST     G023843            NaN
# 1   False  1811  017XX W FULLERTON AV     G005875            NaN
# 2    True  0211    035XX S FEDERAL ST     G012175            NaN
# 3   False  2525     021XX N KEELER AV     G022545            NaN
# 4    True  2031    022XX W AINSLIE ST     G019278            NaN
#
#                       date                     description district  domestic  \
# 0  2001-01-11T23:55:00.000                  $500 AND UNDER      002     False
# 1  2001-01-03T17:15:00.000                  $500 AND UNDER      018     False
# 2  2001-01-06T16:15:00.000    MANU/DELIVER: HEROIN (WHITE)      002     False
# 3  2001-01-10T13:00:00.000                  $500 AND UNDER      025     False
# 4  2001-01-09T00:25:00.000  UNLAWFUL USE OTHER DANG WEAPON      020     False
#
#   fbi_code  ...       latitude  \
# 0       06  ...   41.841421559
# 1       06  ...   41.924983829
# ...

# %%
df2.tail(3)
# Out:
#        arrest  beat                 block case_number community_area  \
# 49997   False  0523  120XX S EGGLESTON AV     G112451            NaN
# 49998   False  1723   041XX N ST LOUIS AV     G112644            NaN
# 49999   False  1434   018XX W CORTLAND ST     G112257            NaN
#
#                           date                    description district  \
# 49997  2001-02-25T20:44:50.000  AGGRAVATED: OTHER DANG WEAPON      005
# 49998  2001-02-25T22:45:00.000                     TO VEHICLE      017
# 49999  2001-02-18T20:05:00.000                         SIMPLE      014
#
#        domestic fbi_code  ...       latitude  \
# 49997      True      04B  ...   41.675992557
# 49998     False       14  ...   41.957251872
# 49999     False      08A  ...   41.916112824
#
#                                                 location location_description  \
# 49997  {'type': 'Point', 'coordinates': [-87.63356992...                ALLEY
# ...

# %%
df3.head(3)
# Out:
#    arrest  beat               block case_number community_area  \
# 0   False  0111   0000X N WACKER DR     G108969            NaN
# 1   False  0633       005XX E 92 ST     G109494            NaN
# 2   False  1032  027XX S MILLARD AV     G111195            NaN
#
#                       date          description district  domestic fbi_code  \
# 0  2001-02-23T17:22:02.000               SIMPLE      001     False      08B
# 1  2001-02-23T23:25:47.000           AUTOMOBILE      006     False       07
# 2  2001-02-25T00:00:48.000  AGGRAVATED: HANDGUN      010     False      04B
#
#    ...       latitude                                           location  \
# 0  ...   41.881976213  {'type': 'Point', 'coordinates': [-87.63716942...
# 1  ...   41.727529967  {'type': 'Point', 'coordinates': [-87.61122112...
# 2  ...   41.841870161  {'type': 'Point', 'coordinates': [-87.71609257...
#
#   location_description      longitude         primary_type  \
# ...

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=50000, step=1)

# %%
df1.columns
# Out:
# Index(['arrest', 'beat', 'block', 'case_number', 'community_area', 'date',
#        'description', 'district', 'domestic', 'fbi_code', 'id', 'iucr',
#        'latitude', 'location', 'location_description', 'longitude',
#        'primary_type', 'updated_on', 'ward', 'x_coordinate', 'y_coordinate',
#        'year'],
#       dtype='object')

# %%
df1.values
# Out:
# array([[False, '0412', '016XX E 86TH PL', ..., nan, nan, '2001'],
#        [True, '1034', '026XX S CALIFORNIA BLVD', ..., '1158280',
#         '1886310', '2017'],
#        [True, '1221', '007XX N SACRAMENTO BLVD', ..., '1156092',
#         '1904769', '2017'],
#        ...,
#        [False, '0513', '108XX S DR MARTN LUTHR KING JR DR', ...,
#         '1180871', '1833258', '2001'],
#        [True, '0232', '051XX S WENTWORTH AV', ..., '1175864', '1871153',
#         '2001'],
#        [False, '1233', '008XX W 19 ST', ..., '1171323', '1891171',
#         '2001']], dtype=object)

# %%
df1['arrest']
# Out:
# 0        False
# 1         True
# 2         True
# 3        False
# 4        False
# 5        False
# 6         True
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13        True
# 14       False
# 15       False
# 16        True
# 17       False
# 18       False
# 19       False
# 20        True
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28        True
# 29       False
#          ...
# 49970     True
# 49971    False
# 49972    False
# 49973    False
# 49974    False
# 49975    False
# 49976    False
# 49977    False
# 49978    False
# 49979     True
# 49980    False
# 49981    False
# 49982    False
# 49983    False
# 49984    False
# 49985    False
# 49986    False
# 49987    False
# 49988    False
# 49989    False
# 49990    False
# 49991    False
# 49992    False
# 49993     True
# 49994    False
# 49995    False
# 49996    False
# ...

# %%
# calculating avg number of missing values per column
df1.isna().sum()/50000
# Out:
# arrest                  0.00000
# beat                    0.00000
# block                   0.00000
# case_number             0.00000
# community_area          0.18104
# date                    0.00000
# description             0.00000
# district                0.00000
# domestic                0.00000
# fbi_code                0.00000
# id                      0.00000
# iucr                    0.00000
# latitude                0.03964
# location                0.03964
# location_description    0.00470
# longitude               0.03964
# primary_type            0.00000
# updated_on              0.00000
# ward                    0.18102
# x_coordinate            0.03964
# y_coordinate            0.03964
# year                    0.00000
# dtype: float64

# %%
train = df1.append(df2, ignore_index=True)

# %%
train.isna().sum()/50000
# Out:
# arrest                  0.00000
# beat                    0.00000
# block                   0.00000
# case_number             0.00000
# community_area          1.17920
# date                    0.00000
# description             0.00000
# district                0.00000
# domestic                0.00000
# fbi_code                0.00000
# id                      0.00000
# iucr                    0.00000
# latitude                0.04034
# location                0.04034
# location_description    0.00470
# longitude               0.04034
# primary_type            0.00000
# updated_on              0.00000
# ward                    1.17916
# x_coordinate            0.04034
# y_coordinate            0.04034
# year                    0.00000
# dtype: float64
